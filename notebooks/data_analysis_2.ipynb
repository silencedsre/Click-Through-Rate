# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('../datasets/data/train_explore.csv')
data.head(10)
# Out:
#    Unnamed: 0  srch_id            date_time  site_id  \
# 0           0        1  2013-04-04 08:32:15       12
# 1           1        1  2013-04-04 08:32:15       12
# 2           2        1  2013-04-04 08:32:15       12
# 3           3        4  2012-12-31 08:59:22        5
# 4           4        4  2012-12-31 08:59:22        5
# 5           5        4  2012-12-31 08:59:22        5
# 6           6        4  2012-12-31 08:59:22        5
# 7           7        6  2013-06-05 12:27:51       14
# 8           8        6  2013-06-05 12:27:51       14
# 9           9        6  2013-06-05 12:27:51       14
#
#    visitor_location_country_id  visitor_hist_starrating  visitor_hist_adr_usd  \
# 0                          187                      NaN                   NaN
# 1                          187                      NaN                   NaN
# 2                          187                      NaN                   NaN
# ...

# %%
def missing_num(x):
    return sum(x.isnull())

# %%
data.apply(missing_num, axis=0)
# Out:
# Unnamed: 0                          0
# srch_id                             0
# date_time                           0
# site_id                             0
# visitor_location_country_id         0
# visitor_hist_starrating        941019
# visitor_hist_adr_usd           940780
# prop_country_id                     0
# prop_id                             0
# prop_starrating                     0
# prop_review_score                1443
# prop_brand_bool                     0
# prop_location_score1                0
# prop_location_score2           218240
# prop_log_historical_price           0
# position                            0
# price_usd                           0
# promotion_flag                      0
# srch_destination_id                 0
# srch_length_of_stay                 0
# srch_booking_window                 0
# srch_adults_count                   0
# srch_children_count                 0
# srch_room_count                     0
# srch_saturday_night_bool            0
# ...

# %%
data.shape
# Out:
# (991752, 55)

# %%
data.drop(data.loc[:, 'comp1_rate':'comp8_rate_percent_diff'].columns, axis=1, inplace=True)
data.drop('gross_bookings_usd', axis=1, inplace=True)

# %%
data.drop(['visitor_hist_starrating', 'visitor_hist_adr_usd', 'srch_query_affinity_score'], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index([u'Unnamed: 0', u'srch_id', u'date_time', u'site_id',
#        u'visitor_location_country_id', u'prop_country_id', u'prop_id',
#        u'prop_starrating', u'prop_review_score', u'prop_brand_bool',
#        u'prop_location_score1', u'prop_location_score2',
#        u'prop_log_historical_price', u'position', u'price_usd',
#        u'promotion_flag', u'srch_destination_id', u'srch_length_of_stay',
#        u'srch_booking_window', u'srch_adults_count', u'srch_children_count',
#        u'srch_room_count', u'srch_saturday_night_bool',
#        u'orig_destination_distance', u'random_bool', u'click_bool',
#        u'booking_bool'],
#       dtype='object')

# %%
data.apply(missing_num, axis=0)
# Out:
# Unnamed: 0                          0
# srch_id                             0
# date_time                           0
# site_id                             0
# visitor_location_country_id         0
# prop_country_id                     0
# prop_id                             0
# prop_starrating                     0
# prop_review_score                1443
# prop_brand_bool                     0
# prop_location_score1                0
# prop_location_score2           218240
# prop_log_historical_price           0
# position                            0
# price_usd                           0
# promotion_flag                      0
# srch_destination_id                 0
# srch_length_of_stay                 0
# srch_booking_window                 0
# srch_adults_count                   0
# srch_children_count                 0
# srch_room_count                     0
# srch_saturday_night_bool            0
# orig_destination_distance      321303
# random_bool                         0
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0        srch_id        site_id  \
# count  991752.000000  991752.000000  991752.000000
# mean   495875.500000  332901.210690       9.961948
# std    286294.286422  192339.604427       7.659477
# min         0.000000       1.000000       1.000000
# 25%    247937.750000  166557.000000       5.000000
# 50%    495875.500000  332826.000000       5.000000
# 75%    743813.250000  499903.000000      14.000000
# max    991751.000000  665574.000000      34.000000
#
#        visitor_location_country_id  prop_country_id        prop_id  \
# count                991752.000000    991752.000000  991752.000000
# mean                    175.409627       174.001521   70132.879704
# std                      65.864661        68.271618   40607.079251
# min                       1.000000         1.000000       1.000000
# 25%                     100.000000       100.000000   35043.000000
# 50%                     219.000000       219.000000   69638.000000
# ...

# %% [markdown]
# # prop_review_score review
#
# - Review is from 0-5
# - mean = 3.778052
# - s.d = 1.050740
#
# - Missing number = 1443

# %%
data['prop_review_score'].plot(bins=10, kind='hist')

# %% [markdown]
# ### Prop review score is negatively skewed
# - So in skewed data, the tail region may act as an outlier for the statistical model and we know that outliers adversely affect the model’s performance especially regression-based models.
# - So necessary to transform this to close enough to Gaussian Distribution or Normal Distribution
#
# #### Log Transformation changes skewed data to Gaussian

# %%
# data['prop_review_score'] = np.log(data['prop_review_score'])
# data['prop_review_score'].plot(bins=10, kind='hist')
# data['prp_review_score'] = np.log(data['prop_review_score'])
data['prop_review_score'] = data['prop_review_score'].apply(lambda x : np.log(x+1))

# %%
data.describe()
# Out:
#           Unnamed: 0        srch_id        site_id  \
# count  991752.000000  991752.000000  991752.000000
# mean   495875.500000  332901.210690       9.961948
# std    286294.286422  192339.604427       7.659477
# min         0.000000       1.000000       1.000000
# 25%    247937.750000  166557.000000       5.000000
# 50%    495875.500000  332826.000000       5.000000
# 75%    743813.250000  499903.000000      14.000000
# max    991751.000000  665574.000000      34.000000
#
#        visitor_location_country_id  prop_country_id        prop_id  \
# count                991752.000000    991752.000000  991752.000000
# mean                    175.409627       174.001521   70132.879704
# std                      65.864661        68.271618   40607.079251
# min                       1.000000         1.000000       1.000000
# 25%                     100.000000       100.000000   35043.000000
# 50%                     219.000000       219.000000   69638.000000
# ...

# %%
data['prop_review_score'].plot(bins=10, kind='hist')

# %% [markdown]
# ## prop_location_score2

# %%
data['prop_location_score2'].plot(kind='hist', bins=10)

# %%
x = data['prop_location_score2'].apply(lambda x : np.log(x+1))
x.plot(bins=10, kind='hist')

# %% [markdown]
# ## orig_destination_distance

# %%
data['orig_destination_distance'].plot(bins-)
